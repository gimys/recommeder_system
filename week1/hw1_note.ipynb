# %%
import pandas as pd
import numpy as np

# %%
tmp_data = pd.read_csv('np-ratings.csv')

# %%
tmp_data
# Out:
#     260: Star Wars: Episode IV - A New Hope (1977)  \
# 0                                              1.0
# 1                                              5.0
# 2                                              NaN
# 3                                              NaN
# 4                                              4.0
# 5                                              2.0
# 6                                              NaN
# 7                                              4.0
# 8                                              5.0
# 9                                              4.0
# 10                                             2.0
# 11                                             3.0
# 12                                             2.0
# 13                                             3.0
# 14                                             4.0
# 15                                             NaN
# 16                                             NaN
# ...

# %%
pd.DataFrame(tmp_data.mean(), columns=['mean']).sort_values(by='mean', ascending=False)[:3]
# Out:
#                                                     mean
# 318: Shawshank Redemption, The (1994)           3.600000
# 260: Star Wars: Episode IV - A New Hope (1977)  3.266667
# 541: Blade Runner (1982)                        3.222222

# %%
pd.DataFrame(tmp_data.count(), columns=['count']).sort_values(by='count', ascending=False)[:3]
# Out:
#                                                 count
# 1: Toy Story (1995)                                17
# 593: Silence of the Lambs, The (1991)              16
# 260: Star Wars: Episode IV - A New Hope (1977)     15

# %%
pd.DataFrame(tmp_data[tmp_data >= 4].count(), columns=['GT_4']).sort_values(by='GT_4', ascending=False)[:3]
# Out:
#                                                 GT_4
# 260: Star Wars: Episode IV - A New Hope (1977)     8
# 318: Shawshank Redemption, The (1994)              7
# 593: Silence of the Lambs, The (1991)              7
